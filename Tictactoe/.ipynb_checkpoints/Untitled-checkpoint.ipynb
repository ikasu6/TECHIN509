# %% [markdown]
# # Analysis on Game DataBase

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#reading the  data base

games_data=pd.read_csv('out.csv',index_col=[0])
li2=games_data.PlayerName[games_data['PlayerStatus']=='Win'] 
li2=list(li2)
Player_won_max=max(li2,key=li2.count)
li2=list(li2)
No_of_times_won=li2.count(Player_won_max)
li2=list(li2)
No_of_games_Played=len(games_data[games_data['PlayerName']==Player_won_max] )
li2=list(li2)
df2=games_data.explode('PlayerName')

li2=list(li2)
res = pd.crosstab(df2['PlayerName'], df2['PlayerStatus'])
res['GamesPlayed']=res['Draw'] + res['NoWin'] + res['Win'] 
li2=list(li2)
res=res[['GamesPlayed', 'Draw', 'NoWin', 'Win']]
res.columns.name = None

# %%
res=res.sort_values('Win',ascending=False)
res.reset_index(inplace=True)
rankboard=res.head(5)

# %%
# Top 5 Plaers
rankboard.plot.barh(x='PlayerName', y='Win',
			title='Top 5 Players', color='Blue')
# Out:
# <AxesSubplot: title={'center': 'Top 5 Players'}, ylabel='PlayerName'>

# %%
res.plot(kind='bar', x='PlayerName', title='Player Statistics')
# Turn on the grid
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.1', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.1', color='black')
plt.show()

# %%
games_data["PlayerType"].value_counts().plot(kind='bar',title='Type of players count')
# Out:
# <AxesSubplot: title={'center': 'Type of players count'}>
